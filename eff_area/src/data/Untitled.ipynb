# %%
import matplotlib.pyplot as plt
import numpy as np
import yaml
import os
lu = [
    "n0",
    "n1",
    "n2",
    "n3",
    "n4",
    "n5",
    "n6",
    "n7",
    "n8",
    "n9",
    "na",
    "nb",
    "b0",
    "b1",
]

# %%
with open(os.path.join(os.environ.get("GBMDATA"),"localizing/trigdat_norms.yml"),"r") as f:
    res = yaml.safe_load(f)

# %%
for d in lu:
    for grb in res.keys():
        norms = []
        for sel in res[grb].keys():
            if sel == "separation":
                sep = res[grb][sel][d]
            else:
                norms.append(res[grb][sel][d])
        plt.scatter(range(len(norms)),norms)
        plt.show()
